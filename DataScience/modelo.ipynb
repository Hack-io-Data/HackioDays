# %%
import pandas as pd
from pycaret.clustering import *
pd.pandas.set_option('display.max_columns', None)

# %%
df = pd.read_csv("Datos/Customers.csv")
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size
# 0         Agent          384.811147   Two-Door Car      Medsize
# 1         Agent         1131.464935  Four-Door Car      Medsize
# 2         Agent          566.472247   Two-Door Car      Medsize
# 3   Call Center          529.881344            SUV      Medsize
# 4         Agent          138.130879  Four-Door Car      Medsize

# %%
# import ClusteringExperiment and init the class
from pycaret.clustering import ClusteringExperiment
exp = ClusteringExperiment()

# init setup on exp
exp.setup(df, session_id = 123)
# Out:
# <style type="text/css">
# #T_50212_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_50212">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_50212_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_50212_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50212_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_50212_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_50212_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_50212_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_50212_row1_col1" class="data row1 col1" >(9134, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_50212_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_50212_row2_col1" class="data row2 col1" >(9134, 9256)</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_50212_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_50212_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_50212_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_50212_row4_col1" class="data row4 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_50212_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_50212_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_50212_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_50212_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_50212_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_50212_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_50212_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_50212_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_50212_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_50212_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_50212_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_50212_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_50212_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_50212_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_50212_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_50212_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_50212_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_50212_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_50212_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_50212_row14_col1" class="data row14 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_50212_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_50212_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_50212_row15_col1" class="data row15 col1" >1975</td>
#     </tr>
#   </tbody>
# </table>

# %%
# train kmeans model
kmeans = create_model('kmeans')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 # train kmeans model
# ----> 2 kmeans = create_model('kmeans')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/contenido/lib/python3.11/site-packages/pycaret/utils/generic.py:963, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     961 for name, message in global_names.items():
#     962     if globals_d[name] is None:
# --> 963         raise ValueError(message)
#     964 return func(*args, **kwargs)
#
# ValueError: _CURRENT_EXPERIMENT global variable is not set. Please run setup() first.

# %%
# to check all the available models
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch

# %%
kmeans_cluster = assign_model(kmeans)
kmeans_cluster
# Out:
#      Customer       State  Customer Lifetime Value Response  Coverage  \
# 0     BU79786  Washington              2763.519287       No     Basic
# 1     QZ44356     Arizona              6979.536133       No  Extended
# 2     AI49188      Nevada             12887.431641       No   Premium
# 3     WW63253  California              7645.861816       No     Basic
# 4     HB64268  Washington              2813.692627       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.988281       No     Basic
# 9130  PK87824  California              3096.511230      Yes  Extended
# 9131  TD14365  California              8163.890625       No  Extended
# 9132  UP19263  California              7524.442383       No  Extended
# 9133  Y167826  California              2611.836914       No  Extended
#
#      Education Effective To Date EmploymentStatus Gender  Income  \
# 0     Bachelor           2/24/11         Employed      F   56274
# 1     Bachelor           1/31/11       Unemployed      F       0
# 2     Bachelor           2/19/11         Employed      F   48767
# 3     Bachelor           1/20/11       Unemployed      M       0
# 4     Bachelor            2/3/11         Employed      M   43836
# ...        ...               ...              ...    ...     ...
# 9129  Bachelor           2/10/11         Employed      M   71941
# 9130   College           2/12/11         Employed      F   21604
# 9131  Bachelor            2/6/11       Unemployed      M       0
# 9132   College            2/3/11         Employed      M   21941
# 9133   College           2/14/11       Unemployed      M       0
#
#      Location Code Marital Status  Monthly Premium Auto  \
# 0         Suburban        Married                    69
# 1         Suburban         Single                    94
# 2         Suburban        Married                   108
# 3         Suburban        Married                   106
# 4            Rural         Single                    73
# ...            ...            ...                   ...
# 9129         Urban        Married                    73
# 9130      Suburban       Divorced                    79
# 9131      Suburban         Single                    85
# 9132      Suburban        Married                    96
# 9133      Suburban         Single                    77
#
#       Months Since Last Claim  Months Since Policy Inception  \
# 0                          32                              5
# 1                          13                             42
# 2                          18                             38
# 3                          18                             65
# 4                          12                             44
# ...                       ...                            ...
# 9129                       18                             89
# 9130                       14                             28
# 9131                        9                             37
# 9132                       34                              3
# 9133                        3                             90
#
#       Number of Open Complaints  Number of Policies     Policy Type  \
# 0                             0                   1  Corporate Auto
# 1                             0                   8   Personal Auto
# 2                             0                   2   Personal Auto
# 3                             0                   7  Corporate Auto
# 4                             0                   1   Personal Auto
# ...                         ...                 ...             ...
# 9129                          0                   2   Personal Auto
# 9130                          0                   1  Corporate Auto
# 9131                          3                   2  Corporate Auto
# 9132                          0                   3   Personal Auto
# 9133                          0                   1  Corporate Auto
#
#             Policy Renew Offer Type Sales Channel  Total Claim Amount  \
# 0     Corporate L3           Offer1         Agent          384.811157
# 1      Personal L3           Offer3         Agent         1131.464966
# 2      Personal L3           Offer1         Agent          566.472229
# 3     Corporate L2           Offer1   Call Center          529.881348
# 4      Personal L1           Offer1         Agent          138.130875
# ...            ...              ...           ...                 ...
# 9129   Personal L1           Offer2           Web          198.234756
# 9130  Corporate L3           Offer1        Branch          379.200012
# 9131  Corporate L2           Offer1        Branch          790.784973
# 9132   Personal L2           Offer3        Branch          691.200012
# 9133  Corporate L3           Offer4   Call Center          369.600006
#
#       Vehicle Class Vehicle Size    Cluster
# 0      Two-Door Car      Medsize  Cluster 2
# 1     Four-Door Car      Medsize  Cluster 3
# 2      Two-Door Car      Medsize  Cluster 2
# 3               SUV      Medsize  Cluster 3
# 4     Four-Door Car      Medsize  Cluster 2
# ...             ...          ...        ...
# 9129  Four-Door Car      Medsize  Cluster 0
# 9130  Four-Door Car      Medsize  Cluster 1
# 9131  Four-Door Car      Medsize  Cluster 3
# 9132  Four-Door Car        Large  Cluster 1
# 9133   Two-Door Car      Medsize  Cluster 3
#
# [9134 rows x 25 columns]

# %%
# plot pca cluster plot 
plot_model(kmeans, plot = 'cluster')

# %%
exp_clu101 = setup(df, normalize = True, 
                   ignore_features = [],
                   session_id = 123)
kmeans = create_model('kmeans')
kmean_results = assign_model(kmeans)
kmean_results.head()
# Out:
# <style type="text/css">
# #T_a0e24_row5_col1, #T_a0e24_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a0e24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0e24_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a0e24_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0e24_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0e24_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a0e24_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0e24_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_a0e24_row1_col1" class="data row1 col1" >(9134, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0e24_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_a0e24_row2_col1" class="data row2 col1" >(9134, 9256)</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0e24_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_a0e24_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0e24_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_a0e24_row4_col1" class="data row4 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0e24_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_a0e24_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0e24_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_a0e24_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a0e24_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_a0e24_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a0e24_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_a0e24_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a0e24_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_a0e24_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a0e24_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_a0e24_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a0e24_row11_col0" class="data row11 col0" >Normalize</td>
#       <td id="T_a0e24_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a0e24_row12_col0" class="data row12 col0" >Normalize method</td>
#       <td id="T_a0e24_row12_col1" class="data row12 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a0e24_row13_col0" class="data row13 col0" >CPU Jobs</td>
#       <td id="T_a0e24_row13_col1" class="data row13 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a0e24_row14_col0" class="data row14 col0" >Use GPU</td>
#       <td id="T_a0e24_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a0e24_row15_col0" class="data row15 col0" >Log Experiment</td>
#       <td id="T_a0e24_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a0e24_row16_col0" class="data row16 col0" >Experiment Name</td>
#       <td id="T_a0e24_row16_col1" class="data row16 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_a0e24_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_a0e24_row17_col0" class="data row17 col0" >USI</td>
#       <td id="T_a0e24_row17_col1" class="data row17 col1" >01c3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b7e7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7e7d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b7e7d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b7e7d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b7e7d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b7e7d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b7e7d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7e7d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7e7d_row0_col0" class="data row0 col0" >0.0002</td>
#       <td id="T_b7e7d_row0_col1" class="data row0 col1" >2.5695</td>
#       <td id="T_b7e7d_row0_col2" class="data row0 col2" >39.9560</td>
#       <td id="T_b7e7d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b7e7d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b7e7d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519287       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.536133       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431641       No   Premium  Bachelor
# 3  WW63253  California              7645.861816       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692627       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# 0        Married                    69                       32
# 1         Single                    94                       13
# 2        Married                   108                       18
# 3        Married                   106                       18
# 4         Single                    73                       12
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# 1                             42                          0
# 2                             38                          0
# 3                             65                          0
# 4                             44                          0
#
#    Number of Policies     Policy Type        Policy Renew Offer Type  \
# 0                   1  Corporate Auto  Corporate L3           Offer1
# 1                   8   Personal Auto   Personal L3           Offer3
# 2                   2   Personal Auto   Personal L3           Offer1
# 3                   7  Corporate Auto  Corporate L2           Offer1
# 4                   1   Personal Auto   Personal L1           Offer1
#
#   Sales Channel  Total Claim Amount  Vehicle Class Vehicle Size    Cluster
# 0         Agent          384.811157   Two-Door Car      Medsize  Cluster 3
# 1         Agent         1131.464966  Four-Door Car      Medsize  Cluster 2
# 2         Agent          566.472229   Two-Door Car      Medsize  Cluster 1
# 3   Call Center          529.881348            SUV      Medsize  Cluster 3
# 4         Agent          138.130875  Four-Door Car      Medsize  Cluster 1

# %%
import sweetviz as sv
